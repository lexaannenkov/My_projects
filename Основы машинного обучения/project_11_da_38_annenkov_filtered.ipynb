# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных" data-toc-modified-id="Изучение-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных</a></span></li><li><span><a href="#EDA" data-toc-modified-id="EDA-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#Посмотрим-статистические-данные" data-toc-modified-id="Посмотрим-статистические-данные-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Посмотрим статистические данные</a></span></li><li><span><a href="#Посмотрим-дубликаты-и-пропуски" data-toc-modified-id="Посмотрим-дубликаты-и-пропуски-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Посмотрим дубликаты и пропуски</a></span></li><li><span><a href="#Посмотрим-на-средние-значения-признаков-в-двух-группах-—-тех,-кто-ушел-в-отток-и-тех,-кто-остался" data-toc-modified-id="Посмотрим-на-средние-значения-признаков-в-двух-группах-—-тех,-кто-ушел-в-отток-и-тех,-кто-остался-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Посмотрим на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался</a></span></li><li><span><a href="#Постром-столбчатые-гистограммы-и-распределения-признаков-для-тех,-кто-ушёл-(отток)-и-тех,-кто-остался-(не-попали-в-отток)" data-toc-modified-id="Постром-столбчатые-гистограммы-и-распределения-признаков-для-тех,-кто-ушёл-(отток)-и-тех,-кто-остался-(не-попали-в-отток)-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Постром столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток)</a></span></li><li><span><a href="#Построим-гисторгаммы-для-тех-кто-остался" data-toc-modified-id="Построим-гисторгаммы-для-тех-кто-остался-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Построим гисторгаммы для тех кто остался</a></span></li><li><span><a href="#Построим-матрицу-корреляций-и-отобразим-её." data-toc-modified-id="Построим-матрицу-корреляций-и-отобразим-её.-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Построим матрицу корреляций и отобразим её.</a></span></li></ul></li><li><span><a href="#Построение-модели-прогназирования-оттока-клиентов" data-toc-modified-id="Построение-модели-прогназирования-оттока-клиентов-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Построение модели прогназирования оттока клиентов</a></span></li><li><span><a href="#Кластеризация-клиентов" data-toc-modified-id="Кластеризация-клиентов-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Кластеризация клиентов</a></span><ul class="toc-item"><li><span><a href="#Стандартизируем-данные" data-toc-modified-id="Стандартизируем-данные-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Стандартизируем данные</a></span></li><li><span><a href="#Построим-матрицу-расстояний-функцией-linkage()-на-стандартизованной-матрице-признаков-и-нарисуем-дендрограмму" data-toc-modified-id="Построим-матрицу-расстояний-функцией-linkage()-на-стандартизованной-матрице-признаков-и-нарисуем-дендрограмму-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Построим матрицу расстояний функцией linkage() на стандартизованной матрице признаков и нарисуем дендрограмму</a></span></li><li><span><a href="#Обучение-модели-кластеризации-на-основании-алгоритма-K-Means-и-прогнозирование-кластеров-клиентов." data-toc-modified-id="Обучение-модели-кластеризации-на-основании-алгоритма-K-Means-и-прогнозирование-кластеров-клиентов.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Обучение модели кластеризации на основании алгоритма K-Means и прогнозирование кластеров клиентов.</a></span></li><li><span><a href="#Построение-распределение-признаков-для-кластеров." data-toc-modified-id="Построение-распределение-признаков-для-кластеров.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Построение распределение признаков для кластеров.</a></span></li><li><span><a href="#Посчитаем-долю-оттока-по-кластерам." data-toc-modified-id="Посчитаем-долю-оттока-по-кластерам.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Посчитаем долю оттока по кластерам.</a></span></li></ul></li><li><span><a href="#Выводы-и-рекомендации" data-toc-modified-id="Выводы-и-рекомендации-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Выводы и рекомендации</a></span></li></ul></div>

# %% [markdown]
# # Проект ML

# %% [markdown]
# Сеть фитнес-центров «Культурист-датасаентист» разрабатывает стратегию взаимодействия с клиентами на основе аналитических данных.
#
# Распространённая проблема фитнес-клубов и других сервисов — отток клиентов. Как понять, что клиент больше не с вами? Можно записать в отток тех, кто попросил закрыть договор или удалил аккаунт. Однако клиенты не всегда уходят демонстративно: чаще перестают пользоваться сервисом тихо.
#
# Индикаторы оттока зависят от специфики отрасли. Когда пользователь редко, но стабильно закупается в интернет-магазине — не похоже, что он «отвалился». А вот если две недели не заходит на канал с ежедневно обновляемым контентом, дела плохи: подписчик заскучал и, кажется, оставил вас.
#
# Для фитнес-центра можно считать, что клиент попал в отток, если за последний месяц ни разу не посетил спортзал. Конечно, не исключено, что он уехал на Бали и по приезде обязательно продолжит ходить на фитнес. Однако чаще бывает наоборот. Если клиент начал новую жизнь с понедельника, немного походил в спортзал, а потом пропал — скорее всего, он не вернётся.
#
# Чтобы бороться с оттоком, отдел по работе с клиентами «Культуриста-датасаентиста» перевёл в электронный вид множество клиентских анкет. Ваша задача — провести анализ и подготовить план действий по удержанию клиентов.
#
# А именно:
# * научиться прогнозировать вероятность оттока (на уровне следующего месяца) для каждого клиента;
# * сформировать типичные портреты клиентов: выделить несколько наиболее ярких групп и охарактеризовать их основные свойства;
# * проанализировать основные признаки, наиболее сильно влияющие на отток;
# * сформулировать основные выводы и разработать рекомендации по повышению качества работы с клиентами:
#     * 1) выделить целевые группы клиентов;
#     * 2) предложить меры по снижению оттока;
#     * 3) определить другие особенности взаимодействия с клиентами.

# %% [markdown]
# ## Изучение данных

# %% [markdown]
# Импорт необходимых библиотек

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
data = pd.read_csv('https://drive.google.com/file/d/1QasMCkCsa27_k64eYQf1rOwn0-KaT0i-/view?usp=sharing')

# %%
data.head(10)
# Out:
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
# 5       1              1        0              0      1                1
# 6       1              1        1              1      0                6
# 7       0              1        0              0      1                1
# 8       1              1        1              1      1                1
# 9       0              1        0              0      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   Near_Location                      4000 non-null   int64
#  2   Partner                            4000 non-null   int64
#  3   Promo_friends                      4000 non-null   int64
#  4   Phone                              4000 non-null   int64
#  5   Contract_period                    4000 non-null   int64
#  6   Group_visits                       4000 non-null   int64
#  7   Age                                4000 non-null   int64
#  8   Avg_additional_charges_total       4000 non-null   float64
#  9   Month_to_end_contract              4000 non-null   float64
#  10  Lifetime                           4000 non-null   int64
# ...

# %% [markdown]
# Таблица состоит из 14 столбцов и 4000 строк:
# * Данные клиента за предыдущий до проверки факта оттока месяц:
#     * `gender` — пол;
#     * `Near_Location` — проживание или работа в районе, где находится фитнес-центр;
#     * `Partner` — сотрудник компании-партнёра клуба (сотрудничество с компаниями, чьи сотрудники могут получать скидки на абонемент — в таком случае фитнес-центр хранит информацию о работодателе клиента);
#     * `Promo_friends` — факт первоначальной записи в рамках акции «приведи друга» (использовал промо-код от знакомого при оплате первого абонемента);
#     * `Phone` — наличие контактного телефона;
#     * `Age` — возраст;
#     * `Lifetime` — время с момента первого обращения в фитнес-центр (в месяцах).
# * Информация на основе журнала посещений, покупок и информация о текущем статусе абонемента клиента:
#     * `Contract_period` — длительность текущего действующего абонемента (месяц, 6 месяцев, год);
#     * `Month_to_end_contract` — срок до окончания текущего действующего абонемента (в месяцах);
#     * `Group_visits` — факт посещения групповых занятий;
#     * `Avg_class_frequency_total` — средняя частота посещений в неделю за все время с начала действия абонемента;
#     * `Avg_class_frequency_current_month` — средняя частота посещений в неделю за предыдущий месяц;
#     * `Avg_additional_charges_total` — суммарная выручка от других услуг фитнес-центра: кафе, спорттовары, косметический и массажный салон.
#     * `Churn` — факт оттока в текущем месяце.

# %% [markdown]
# ## EDA

# %% [markdown]
# Приведем названия столбцов к нижнему регистру

# %%
data.columns = data.columns.str.lower()
data.head()
# Out:
#    gender  near_location  partner  promo_friends  phone  contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    group_visits  age  avg_additional_charges_total  month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# 1             1   31                    113.202938                   12.0
# 2             0   28                    129.448479                    1.0
# 3             1   33                     62.669863                   12.0
# 4             0   26                    198.362265                    1.0
#
#    lifetime  avg_class_frequency_total  avg_class_frequency_current_month  \
# ...

# %% [markdown]
# ### Посмотрим статистические данные

# %%
data.describe().T
# Out:
#                                     count        mean        std        min  \
# gender                             4000.0    0.510250   0.499957   0.000000
# near_location                      4000.0    0.845250   0.361711   0.000000
# partner                            4000.0    0.486750   0.499887   0.000000
# promo_friends                      4000.0    0.308500   0.461932   0.000000
# phone                              4000.0    0.903500   0.295313   0.000000
# contract_period                    4000.0    4.681250   4.549706   1.000000
# group_visits                       4000.0    0.412250   0.492301   0.000000
# age                                4000.0   29.184250   3.258367  18.000000
# avg_additional_charges_total       4000.0  146.943728  96.355602   0.148205
# month_to_end_contract              4000.0    4.322750   4.191297   1.000000
# lifetime                           4000.0    3.724750   3.749267   0.000000
# ...

# %% [markdown]
# * 1. Распределение клиентов по половому признаку 50/50.
# * 2. Примерно 80% клиентов проживают в районе где находится фитнес.
# * 3. Около 50% клиентов являются сотрудниками компании-партнёра клуба.
# * 4. Около 30% клиентов пришли в фитнес в рамках акции «приведи друга».
# * 5. У 90% клиентов указан контактный телефон.
# * 6. Длительность текущего действующего абонимента у всех разная, в среднем составляет 4-5 месяцев, медиана 1 месяц, максимум 12 месяцев.
# * 7. Групповые занятия посещают 41% клиентов.
# * 8. Средний возраст клиентов как и медиана 29 лет, минимум 18 лет и максимум 41 год.
# * 9. Средние расходы клиентов на сопутствующие услуги и товары составляют 146 долларов, медиана 136 долларов, максимальные расходы 552 доллара.
# * 10. Средний срок до окончания действующего абонимента около 4 месяцев, медиана 1 месяц, это говорит о том что присутствуют выбросы.
# * 11. Среднее время с момента первого обращения в фитнес около 4 месяцев, максимальное 31 месяц.
# * 12. Средняя частота посещений в неделю за все время с начала действия абонемента составляет 2 раза, медиана тоже около 2-х, максимальное 6.
# * 13. Средняя частота посещений в неделю за предыдущий месяц около 2 раз, медиана также.
# * 14. Отток клиентов в текущем месяце составил в среднем 26%.
#
# Самое большое стандартное отклонение у колонки `avg_additional_charges_total` 96,3, у остальных в диапазоне 0,3 - 4.

# %% [markdown]
# ### Посмотрим дубликаты и пропуски

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов не найдено

# %% [markdown]
# Посмотрим пропуски

# %%
data.isna().sum()
# Out:
# gender                               0
# near_location                        0
# partner                              0
# promo_friends                        0
# phone                                0
# contract_period                      0
# group_visits                         0
# age                                  0
# avg_additional_charges_total         0
# month_to_end_contract                0
# lifetime                             0
# avg_class_frequency_total            0
# avg_class_frequency_current_month    0
# churn                                0
# dtype: int64

# %% [markdown]
# Пропусков тоже нет

# %% [markdown]
# ### Посмотрим на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался

# %%
data.groupby('churn')['gender'].sum()
# Out:
# churn
# 0    1499
# 1     542
# Name: gender, dtype: int64

# %% [markdown]
# Отток в текущем месяце составил 1499 человек

# %%
data.groupby('churn').mean().T
# Out:
# churn                                       0           1
# gender                               0.510037    0.510839
# near_location                        0.873086    0.768143
# partner                              0.534195    0.355325
# promo_friends                        0.353522    0.183789
# phone                                0.903709    0.902922
# contract_period                      5.747193    1.728558
# group_visits                         0.464103    0.268615
# age                                 29.976523   26.989632
# avg_additional_charges_total       158.445715  115.082899
# month_to_end_contract                5.283089    1.662582
# lifetime                             4.711807    0.990575
# avg_class_frequency_total            2.024876    1.474995
# avg_class_frequency_current_month    2.027882    1.044546

# %% [markdown]
# * Распределение по половому признаку примерно равное для тех кто ушел и для тех кто остался.
# * 76% "ушедших" проживают в районе где находится фитнес.
# * 35% "ушедших" пришли в фитнес в рамках акции «приведи друга».
# * Данные о контактном номере телефона есть о 90% клиентов как "ушедших", так и оставшихся.
# * У "ушедших" клиентов оставалось еще 1-2 месяца абонимента, у оставшихся 5-6 месяцев.
# * Среди "ушедших" 26% клиентов посещали групповые занятия.
# * Средний возраст "ушедших" клиентов 27 лет.
# * Средние расходы "ушедших" клиентов составляют 115 долларов.
# * В среднем у "ушедших" клиентов оставался 1,6 месяцев абонимента, у оставшихся 5,2 месяца.
# * Время с момента первого обращения в фитнес у "ушедших" клиентов составляло 1 месяц, у оставшихся 4-5 месяцев.
# * В среднем "ушедшие" клиенты посещали фитнес 1,47 раз в неделю, оставшиеся 2 раза.
# *  Посещения за предыдущий месяц у "ушедших" клиентов составляло 1 раз в неделю, у оставшихся так же 2 раза.

# %% [markdown]
# ### Постром столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток)

# %%
churn_1 = data.query('churn == 1')
churn_0 = data.query('churn == 0')
columns = data.drop(columns=['churn']).columns.tolist()

# %%
def just_hist(data, columns):
    for i in columns:
        plt.figure(figsize =(10, 6))
        sns.distplot(data[i], kde=False)
        plt.title('Распределение признака {}'.format(i)) #подпись заголовка
        plt.xlabel('Значение') #подпись оси х
        plt.ylabel('Частота') #подпись оси у
        plt.grid() 
        plt.show()

# %% [markdown]
# Построим гисторгаммы для тех кто ушел.

# %%
just_hist(churn_1, columns)
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Выводы из графиков для тех, кто ушел (отток):
#
# * Гендерное распределение примерно 50 на 50.
# * У большинства ушедших фитнес находился рядом с домом или работой около 80%
# * Большинство ушедших клиентов примерно 70% - это не сотрудники компаний-партнёров клуба
# * Большинство клиентов из оттока >80% пришли не по акции "приведи друга"
# * Практически все клиенты оставили контанктный номер телефона около 90%
# * Длительность текущего действующего абонемента для ушедших клиентов в большинстве своём составляет 1 месяц. У оставшегося иеньшинства длительность абонемента 6 месяцев
# * Из числа ушедших клиентов большая часть не ходила на групповые занятия, почти 80%, оставшиеся 20% занятия посещали
# * Распределение возраста - нормальное, медиана находится в районе 27 лет
# * Рапределение трат на сопутствующие товары и услуги смещено влево
# * У большинства ушедших до окончания абонемента оставался 1 месяц
# * Медианное время с момента первого обращения в фитнес - 1 месяц. Также довольно мнго тех, кто состоял в фитнесе меньше месяца
# * Распределение средней частоты посещений в неделю за все время с начала действия абонемента - нормальное.
# * Медианное значение средней частоты посещений в неделю за предыдущий месяц около 1. Это может значить, что те, кто ушел, стали ходить реже в последний месяц

# %% [markdown]
# ### Построим гисторгаммы для тех кто остался

# %%
just_hist(churn_0, columns)

# %% [markdown]
# Выводы из графиков для тех, кто остался (не попали в отток):
#
# * Гендерное распределение примерно 50 на 50
# * У большинства оставшихся фитнес находится рядом с домом или работой
# * Чуть больше половины оставшихся клиентов - это сотрудники компаний-партнёров клуба
# * Большая часть оставшихся клиентов 2/3 пришли не по акции "приведи друга"
# * Практически все клиенты оставили контанктный номер телефона
# * Длительность текущего действующего абонемента для ушедших клиентов - 1 месяц(~40%), 12 месяцев (~ 35%) и 6 месяцев (~ 25%)
# * Из числа оставшихся клиентов большая часть не ходит на групповые занятия 55%, оставшиеся 45% занятия посещают.
# * Распределение возраста - нормальное, медиана находится в районе 30 лет
# * Рапределение трат на сопутствующие товары и услуги смещено влево
# * У большего числа оставшихся, около 43%, до окончания абонемента остается 1 месяц, число тех, у кого осталось 6 и 12 месяцев до конца примерно одинаковое по 20%
# * Медианное время с момента первого обращения в фитнес-центр - 4 месяца
# * Распределение средней частоты посещений в неделю за все время с начала действия абонемента - нормальное. Оставшиеся клиенты ходят чаще, чем ушедшие.
# * Медианное значение средней частоты посещений в неделю за предыдущий месяц тоже нормальное. Медианы одинаковые, это может значить, что у тех, кто остался, посещение клуба стало привычкой, и посещаемость закрепилась.

# %% [markdown]
# ### Построим матрицу корреляций и отобразим её.

# %%
plt.figure(figsize =(15, 10))
sns.heatmap(data.corr(), annot = True, fmt ='.2g', vmin=-1, vmax=1, center= 0, cmap= 'coolwarm') 
plt.show()

# %% [markdown]
# Видим, что длительность текущего действующего абонемента хорошо коррелирует со сроком до окончания текущего действующего абонемента (0.97). Также хорошая корреляция заметна между средней частотой посещений в неделю за все время с начала действия абонемента и средней частотой посещений в неделю за предыдущий месяц (0.95).
#
# Корелляция послабее (0.45) наблюдается между призаком 'Partner' (сотрудник компании-партнёра клуба) и признаком Promo_friends (факт первоначальной записи в рамках акции «приведи друга»). Возможно, коллеги по работе рекомендовали клуб другим своим коллегам.
#
# Почистим явно дублирующиеся признаки - удалим по одному признаку в каждой паре. На случайный лес это аффектить не должно, но всё равно это будет хорошим тоном - исключить мультиколлинеарность.

# %%
#исключим мультиколлинеарность
data = data.drop(columns=['contract_period', 'avg_class_frequency_current_month'])

# %% [markdown]
# ## Построение модели прогназирования оттока клиентов

# %% [markdown]
# Раздели выборку на обучающую и валидационную

# %%
#разделим наши данные на признаки (матрица X) и целевую переменную (y)
X = data.drop(columns = ['churn'], axis=1)
y = data['churn']

#разделяем модель на обучающую и валидационную выборки
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# Создадим функцию которая будет выводить метрики

# %%
# зададим список моделей
models = [
    LogisticRegression(random_state=0),
    RandomForestClassifier(random_state=0)
]

# функция, которая принимает на вход модель и данные и выводит метрики
def make_prediction(m, X_train, y_train, X_test, y_test):
    model = m
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(
        'Accuracy:{:.2f} Precision:{:.2f} Recall:{:.2f}'.format(
            accuracy_score(y_test, y_pred),
            precision_score(y_test, y_pred),
            recall_score(y_test, y_pred),
        )
    )

# %% [markdown]
# Посмотрим метрики accuracy, precision и recall

# %%
for i in models:
    print(i)
    make_prediction(
        m=i,
        X_train=X_train,
        y_train=y_train,
        X_test=X_test,
        y_test=y_test
    )
# Out:
# LogisticRegression(random_state=0)
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy:0.88 Precision:0.75 Recall:0.74
# RandomForestClassifier(random_state=0)
# Accuracy:0.90 Precision:0.80 Recall:0.77

# %% [markdown]
# Модель случайный лес показала себя лучше.

# %% [markdown]
# ## Кластеризация клиентов

# %% [markdown]
# ### Стандартизируем данные

# %%
# стандартизируем данные
sc = StandardScaler()
X_sc = sc.fit_transform(X)

linked = linkage(X_sc, method = 'ward')

# %% [markdown]
# ### Построим матрицу расстояний функцией linkage() на стандартизованной матрице признаков и нарисуем дендрограмму

# %%
plt.figure(figsize=(15, 10))  
dendrogram(linked, orientation='top')
plt.title('Кластеризация пользователей')
plt.show()

# %% [markdown]
# На основании полученного графика можно выделить 4 кластера. Так как 4 кластер - довольно объёмный, разделим выборку на 5 кластеров. После оценки оптимального числа кластеров можно запустить более быстрый алгоритм K-Means.

# %% [markdown]
# ### Обучение модели кластеризации на основании алгоритма K-Means и прогнозирование кластеров клиентов.

# %%
km = KMeans(n_clusters=5, random_state=0) # задаём число кластеров, равное 5, и фиксируем значение random_state для воспроизводимости результата
labels = km.fit_predict(X_sc) # применяем алгоритм к данным и формируем вектор кластеров

# %% [markdown]
# Средние значения признаков для кластеров.

# %%
# сохраняем метки кластера в поле нашего датасета
data['cluster'] = labels

# %%
#посмотрим на численность кластеров
data['cluster'].value_counts()
# Out:
# 3    1158
# 0    1001
# 2     898
# 1     557
# 4     386
# Name: cluster, dtype: int64

# %%
data.groupby(['cluster']).mean().T
# Out:
# cluster                                0           1           2           3  \
# gender                          0.498501    0.500898    0.521158    0.512090
# near_location                   0.995005    0.000000    0.995546    1.000000
# partner                         0.889111    0.488330    0.417595    0.196891
# promo_friends                   1.000000    0.077199    0.011136    0.053541
# phone                           1.000000    1.000000    1.000000    1.000000
# group_visits                    0.519481    0.231598    0.546771    0.297064
# age                            29.543457   28.685817   30.805122   27.818653
# avg_additional_charges_total  152.139417  137.277472  177.103564  124.625600
# month_to_end_contract           6.265734    2.804309    6.162584    1.898964
# lifetime                        4.210789    2.978456    5.701559    2.058722
# avg_class_frequency_total       1.951909    1.762672    2.318701    1.539284
# ...

# %% [markdown]
# После разделения на 5 кластеров можно выявить следующие закономерности:
#
# * 1. В 0 кластере собраны клиенты, которые живут близко к фитнесу и пришли по акции друзей. Большинство - это сотрудники компании-партнёра клуба. В фитнес они ходят около 4 месяцев, на сопутствующие товары и услуги тратят довольно много, 152 долларов, а до прекращения абонимента у них осталось около 6 месяцев. Средняя частота посещений в неделю за все время с начала действия абонемента около 2-х раза в неделю.
#
# * 2. В 1 кластере собраны клиенты, которые пришли не по акции друзей, живут далеко от фитнеса и почти не ходят на групповые занятия. Отток таких клиентов доволько большой примерно 40%.
#
# * 3. Во 2 кластере собраны клиенты, которые живут близко к фитнесу, пришли не по акции друзей, со средней активностью посещают групповые занятия. Средний возраст - 31 год, на сопутствующие товары и услуги тратят довольно много 177 долларов, а до прекращения абонимента у них осталось около 6 месяцев. Средняя частота посещений в неделю за все время с начала действия абонемента около 2-х раз в неделю. Отток таких клиентов совсем небольшой, примерно 1%.
#
# * 4. В 3 кластере собраны клиенты, которые живут/работают около фитнеса. Большинство - это не сотрудники компании-партнёра клуба и пришли не по акции друзей. Они редко посещают групповые занятия, довольно немного тратят на сопутствующие товары и услуги 124 доллара, у них скоро закончится абонимент (осталось 2 месяца), при этом они сами недавно начали заниматься в фитнесе. Отток таких клиентов большой, примерно 50%.
#
# * 5. В 4 кластере собраны клиенты, не оставившие номер телефона. Живут они довольно близко к фитнесу, половина из клиентов - сотрудники компании-партнёра клуба. До окончания абонимента у них около 4 месяцев, отток таких клиенов небольшой, примерно 26%.

# %% [markdown]
# ### Построение распределение признаков для кластеров.

# %%
#построим countplot-графики для бинарных признаков
for column in ['gender', 'near_location', 'partner', 'promo_friends', 'phone', 'group_visits', 'churn']:
    plt.figure(figsize=(15, 10))
    sns.countplot(x = data[column], hue='cluster', data=data)
    plt.title(column)
    plt.grid()
    plt.show()

# %% [markdown]
# * **Признак gender**
#     * Гендерное распределение по кластерам примерно одинаковое, во 2,3,4 кластерах немного превалирует пол 1.
# * **Признак near_location**
#     * В кластерах 0, 2, 3, 4 клиенты проживают или работают в районе, где находится фитнес. Кластер 1 содержит клиентов, которые живут в других районах, дальше от фитнеса.
# * **Признак partner**
#     * В кластере 0 большая часть клиентов - сотрудники компании-партнёра фитнеса. В кластерах 1 и 2, 4 почти половина клиентов - это сотрудники компании-партнёра клуба. В кластере 3 сосредоточены клиенты, не являющиеся сотрудниками партнеров клуба.
# * **Признак promo_friends**
#     * В кластере 0 все клиенты пришли в рамках акции «приведи друга», в кластерах 1,2,3 большая часть клиентов пришла в фитнес без акции «приведи друга», в кластере 4, 30% клиентов пришли в рамках акции «приведи друга».
# * **Признак phone**
#     * Только в кластере 4 клиенты не оставляли данных о номере телефона.
# * **Признак group_visits**
#     * Половина клиентов из кластеров 0, 2 посешала групповые занятия, а вторая половина - не посешала. Большинство клиентов из кластера 1, 3, 4 не ходили на групповые занятия.
# * **Признак churn**
#     * В 0 и 2 кластерах собраны клиенты с меньшим оттоком, в 1 и 3 кластерах средний отток больше.

# %%
#построим kdeplot-графики для остальных признаков
for column in ['age', 'month_to_end_contract', 'lifetime', 'avg_class_frequency_total', 'avg_additional_charges_total']:
    plt.figure(figsize=(15, 10))
    sns.kdeplot(data.query('cluster == 0')[column], label = 'Кластер 0')
    sns.kdeplot(data.query('cluster == 1')[column], label = 'Кластер 1')
    sns.kdeplot(data.query('cluster == 2')[column], label = 'Кластер 2')
    sns.kdeplot(data.query('cluster == 3')[column], label = 'Кластер 3')
    sns.kdeplot(data.query('cluster == 4')[column], label = 'Кластер 4')
    plt.legend()
    plt.grid()
    plt.title(column)
    plt.show()

# %% [markdown]
# * **Признак age**
#     * Во всех кластерах возраст распределен равномеро и находится в районе 28-31 год.
# * **Признак month_to_end_contract**
#     * Меньше всего времении до окончания абонимента осталось у клиентов из кластера 3, около 2 месяцев, больше всего времени есть у калстеров 0 и 2, около 6 месяцев.
# * **Признак lifetime**
#     * Среднее время с момента первого обращения в фитнес у кластеров 0,1,3,4 составляет 2 месяцев, у клиентов из кластера 2, 3 месяца.
# * **Признак avg_class_frequency_total**
#     * Самая высокая средняя частота посещений в неделю у кластера 2, 2,5 раза внеделю, самая низкая - у кластера 3, около 1,23 раз.
# * **Признак avg_additional_charges_total**
#     * Чуть больше трат замечено в кластерах 0, 4 и 2, в районе 110 - 160 долларов, меньше в кластере 3 и 1, в районе 50 - 70 долларов.

# %% [markdown]
# ### Посчитаем долю оттока по кластерам.

# %%
fraction = data.groupby('cluster')['churn'].sum() / data.groupby('cluster')['churn'].count()
fraction.sort_values()
# Out:
# cluster
# 2    0.016704
# 0    0.132867
# 4    0.266839
# 1    0.402154
# 3    0.506045
# Name: churn, dtype: float64

# %% [markdown]
# Кластеры 1 и 3 склонны к оттоку, отток составил 40% и 50% соответственно. Более надежные кластеры 2 и 0 в них отток составил 2% и 13%.

# %% [markdown]
# ## Выводы и рекомендации

# %% [markdown]
# В проекте был проведен анализ данных о клиентах сети фитнес-центров «Культурист-датасаентист».
#
# Сформированы типичные портреты клиентов:
#
# * **1 группа** - Клиенты с малым оттоком 13%, живут или работают около фитнеса, большинство пришло от компании-партнера, пришли по рекомендации друзей и акции "Приведи друга" (то есть, возможно, кто-то занимается коллективно), с умеренной частотностью посещают групповые занятия 50%, довольно прилично в среднем тратят на сопутствующие товары и услуги 152 доллара, являются посетителями фитнеса, 4 месяца.
#
# * **2 группа** - Клиенты с довольно большим оттоком 40%, живут не в том районе, где находится фитнес (то есть, им требуется время на дорогу), пришли сами, не по акции "Приведи друга", и почти не ходят на групповые занятия, являются посетителями фитнеса 3 месяца.
#
# * **3 группа** - Клиенты с большим оттоком 50%, большинство клиентов пришло само по себе, не по акции "Приведи друга", мало посещают групповые занятия 23%, немного тратят на сопутствующие товары и услуги 124 долларов, у них скоро закончится абонимент (осталось 2 месяца), при этом они сами недавно начали заниматься в клубе, около 2 месяцев.
#
# Проанализированы основные признаки, наиболее сильно влияющие на отток. Это признак 'Near_Location' (проживание или работа в районе, где находится фитнес), признак 'Promo_friends' (факт первоначальной записи в рамках акции «приведи друга»), признак 'Group_visits' (факт посещения групповых занятий) и признак 'Lifetime' (время с момента первого обращения в фитнес-центр).
#
# **Выводы на основании этих признаков:**
#
# * Если клиент стал реже ходить на групповые тренировки, то есть большой шанс на отток клиента.
# * Если клиент живет далеко, и ему требуется время на дорогу, то вероятность оттока выше, на удержание таких клиентов следует направить больше усилий.
# * Если клиент пришел сам по себе, не по акции "Приведи друга", то есть шанс, что он уйдет. Таких клиентов следует заинтересовать групповыми занятиями, так как коллективный спорт и новые знакомства стимулируют клиентов чаще и дольше ходить в фитнес, так как происходит завязывание и укрепление новых социальных связей.
# * Те, кто в клуб пришел недавно, могут остаться незаинтересованными и в скором времени покинуть клуб, поэтому на "свежих" клиентов нужно направить больше усилий по удержанию, так как атмосфера фитнеса, обстановка и персонал для них новы, нужно в первое время окружить их большим вниманием и заботой, чтобы клиент почувствовал себя комфортно и привык к новому месту.
#
# **Примеры реализации принципов взаимодействия с клиентами и их удержания в виде маркетинговых действий:**
#
# * Взаимодействие в соцсетях: активное ведение страниц фитнеса в соцсетях и продвижение. Создать атмосферу, чтобы клиенты ощущали чувство принадлежности к сообществу фитнеса.
# * Улучшение и поддержание интерьера фитнеса и работоспособности тренажеров, чтобы клиентам было так же комфортно заниматься в нем, как раньше.
# * Проведение коллективных активностей в клубе (бесплатные тренировки по субботам, различные мероприятия после занятий или по вечерам; организация специальных фитнес-мероприятий).
# * Индивидуальный подход к клиентам (заинтересованность их успехами, предложение советов и помощи, чтобы их поддержать). Так клиенты будут знать, что они нам небезразличны.
